# %% [markdown]
# # Clasificador IUS-Digitalis (Demo)
# Este notebook es un **placeholder**. Sustituya por su entrenamiento real.

# %%
from pathlib import Path
docs = list((Path('..')/'rpa_secop'/'out').glob('*.pdf'))
pred = {p.name: ('CONTRATO' if '1' in p.name else 'POLIZA') for p in docs}
pred
